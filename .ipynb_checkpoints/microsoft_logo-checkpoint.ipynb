# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = np.ones((600,1000,3), dtype="uint8")*160
plt.imshow(image)

# %%
#red
image[200:295 , 200:295] = (246,83,20)
#green
image[200:295 , 305:400] = (124,187,0)
#blue
image[305:400 , 200:295] = (0,161,241)
#yellow
image[305:400 , 305:400] = (255,187,0)

plt.imshow(image)

# %%
cv2.putText(image, 'Microsoft' , (400,330), cv2.FONT_HERSHEY_SIMPLEX, 3, (0,0,0), 4)
plt.imshow(image)
